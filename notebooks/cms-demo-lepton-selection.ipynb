# %%
from func_adl_servicex import ServiceXSourceCMSRun1AOD
import awkward as ak
from hist import Hist
import mplhep as mpl

# %%
data_muon = (ServiceXSourceCMSRun1AOD("cernopendata://1507")
        .Select(lambda e: {"m": e.Muons("muons"), "p": e.Vertex("offlinePrimaryVertices")[0].position()})
        .Select(lambda i:
                (
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p))
                                        + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error())
                                          + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.p()),
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p))
                                        + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error())
                                          + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.pt()),
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p)) + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error()) + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.px()),
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p)) + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error()) + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.py()),
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p)) + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error()) + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.pz()),
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p)) + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error()) + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.charge())
                )
                )
        .AsAwkwardArray(['mu_p', 'mu_pt', 'mu_px', 'mu_py', 'mu_pz', 'mu_charge'])).value()
# Out:
# ---------------------------------------------------------------------------
# ServiceXException                         Traceback (most recent call last)
# /tmp/ipykernel_4575/1609692986.py in <module>
# ----> 1 data_muon = (ServiceXSourceCMSRun1AOD("cernopendata://1507")
#       2         .Select(lambda e: {"m": e.Muons("muons"), "p": e.Vertex("offlinePrimaryVertices")[0].position()})
#       3         .Select(lambda i:
#       4                 (
#       5                     i.m
#
# /opt/conda/lib/python3.8/site-packages/make_it_sync/func_wrapper.py in wrapped_call(*args, **kwargs)
#      61         @wraps(fn)
#      62         def wrapped_call(*args, **kwargs):
# ---> 63             return _sync_version_of_function(fn, *args, **kwargs)
#      64
#      65         return wrapped_call
#
# /opt/conda/lib/python3.8/site-packages/make_it_sync/func_wrapper.py in _sync_version_of_function(fn, *args, **kwargs)
#      24         future = exector.submit(get_data_wrapper, *args, **kwargs)
#      25
# ---> 26         return future.result()
#      27
#      28
#
# /opt/conda/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /opt/conda/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# /opt/conda/lib/python3.8/concurrent/futures/thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# /opt/conda/lib/python3.8/site-packages/make_it_sync/func_wrapper.py in get_data_wrapper(*args, **kwargs)
#      19             asyncio.set_event_loop(loop)
#      20             assert not loop.is_running()
# ---> 21             return loop.run_until_complete(fn(*args, **kwargs))
#      22
#      23         exector = ThreadPoolExecutor(max_workers=1)
#
# /opt/conda/lib/python3.8/asyncio/base_events.py in run_until_complete(self, future)
#     614             raise RuntimeError('Event loop stopped before Future completed.')
#     615
# --> 616         return future.result()
#     617
#     618     def stop(self):
#
# /opt/conda/lib/python3.8/site-packages/func_adl/object_stream.py in value_async(self, executor, title)
#     252
#     253         # Run it
# --> 254         return await exe(self._q_ast, title)
#     255
#     256     value = make_sync(value_async)
#
# /opt/conda/lib/python3.8/site-packages/func_adl_servicex/ServiceX.py in execute_result_async(self, a, title)
#     167         # Run ghe query for real!
#     168         attr = getattr(self._ds, name)
# --> 169         return await attr(q_str, title=title)
#     170
#     171
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex_utils.py in cached_version_of_fn(*args, **kwargs)
#      47         try:
#      48             logger.debug(f'{h} - processing request')
# ---> 49             result = await fn(*args, **kwargs)
#      50             sx._cache.set_inmem(h, result)
#      51         finally:
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex.py in get_data_rootfiles_async(self, selection_query, title)
#     274     async def get_data_rootfiles_async(self, selection_query: str,
#     275                                        title: Optional[str] = None) -> List[Path]:
# --> 276         return await self._file_return(selection_query, 'root-file', title)
#     277
#     278     async def get_data_rootfiles_stream(self, selection_query: str,
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex.py in _file_return(self, selection_query, data_format, title)
#     426             return f
#     427
# --> 428         return await self._data_return(selection_query, convert_to_file, title, data_format)
#     429
#     430     @on_exception_itr(backoff.constant, ServiceXUnknownRequestID, interval=0.1, max_tries=3)
#
# /opt/conda/lib/python3.8/site-packages/backoff/_async.py in retry(*args, **kwargs)
#     131
#     132             try:
# --> 133                 ret = await target(*args, **kwargs)
#     134             except exception as e:
#     135                 giveup_result = await giveup(e)
#
# /opt/conda/lib/python3.8/site-packages/backoff/_async.py in retry(*args, **kwargs)
#     131
#     132             try:
# --> 133                 ret = await target(*args, **kwargs)
#     134             except exception as e:
#     135                 giveup_result = await giveup(e)
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex.py in _data_return(self, selection_query, converter, title, data_format)
#     524                                 on the converter call.
#     525         '''
# --> 526         all_data = {
#     527             f.file: f.data
#     528             async for f in self._stream_return(selection_query, title, converter, data_format)
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex.py in <dictcomp>(.0)
#     524                                 on the converter call.
#     525         '''
# --> 526         all_data = {
#     527             f.file: f.data
#     528             async for f in self._stream_return(selection_query, title, converter, data_format)
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex.py in _stream_return(self, selection_query, title, converter, data_format)
#     563                    self._stream_local_files(selection_query, title, data_format))  # type: ignore
#     564
# --> 565         async for r in as_data:
#     566             yield r
#     567
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex.py in <genexpr>(.0)
#     559                                 on the converter call.
#     560         '''
# --> 561         as_data = (StreamInfoData(f.file, await asyncio.ensure_future(converter(f.path)))
#     562                    async for f in
#     563                    self._stream_local_files(selection_query, title, data_format))  # type: ignore
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex.py in _stream_local_files(self, selection_query, title, data_format)
#     596              self._get_files(selection_query, data_format, notifier, title))  # type: ignore
#     597
# --> 598         async for name, a_path in as_files:
#     599             yield StreamInfoPath(name, Path(await a_path))
#     600
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex.py in <genexpr>(.0)
#     593         # Get all the files
#     594         as_files = \
# --> 595             (f async for f in
#     596              self._get_files(selection_query, data_format, notifier, title))  # type: ignore
#     597
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex.py in _get_files(self, selection_query, data_type, notifier, title)
#     633
#     634             # Get a request id - which might be cached, but if not, submit it.
# --> 635             request_id = await self._get_request_id(client, query)
#     636
#     637             # Make sure cache status exists (user could have deleted, see #176)
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex.py in _get_request_id(self, client, query)
#     685         request_id = self._cache.lookup_query(query)
#     686         if request_id is None:
# --> 687             request_info = await self._servicex_adaptor.submit_query(client, query)
#     688             request_id = request_info['request_id']
#     689             self._cache.set_query(query, request_id)
#
# /opt/conda/lib/python3.8/site-packages/servicex/servicex_adaptor.py in submit_query(self, client, json_query)
#      64                 # handle as needed.
#      65                 t = await response.text()
# ---> 66                 raise ServiceXException('ServiceX rejected the transformation request: '
#      67                                         f'({status}){t}')
#      68
#
# ServiceXException: (ServiceXException(...), 'ServiceX rejected the transformation request: (400){"message": "Failed to submit transform request: Failed to generate translation code: Unknown id: isNonnull"}\n')

# %%
h = (Hist.new
     .Reg(50, 0, 200, name='mu_pt', label='Muon $p_T$')
     .Int64()
     )
h.fill(ak.flatten(data_muon['mu_pt']))
_ = h.plot()

# %%
print(data_muon['mu_p'])

# %%
data_electron = (ServiceXSourceCMSRun1AOD("cernopendata://1507") 
        .Select(lambda e: {"m": e.GsfElectrons("gsfElectrons"), "p": e.Vertex("offlinePrimaryVertices")[0].position()})
        .Select(lambda i:
                (
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.p()),
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.pt()),
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.px()),
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.py()),
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.pz()),
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.charge()),
                )
                )
        .AsAwkwardArray(['el_p', 'el_pt', 'el_px', 'el_py', 'el_pz', 'el_charge']).value())

# %%
h = (Hist.new
     .Reg(50, 0, 200, name='el_pt', label='GsfElectron $p_T$')
     .Int64()
     )
h.fill(ak.flatten(data_electron['el_pt']))
_ = h.plot()
